# %%
import pandas as pd
from transliterate import translit
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import re
import warnings
warnings.filterwarnings('ignore')

# %%
# задать количество столбцов и строк отображения датафрейма
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
# тема для графиков по умалчанию - plotly_white рекомендуется для презентаций
pio.templates.default = "plotly_white"

# %% [markdown]
# ### Подготовить чистый датасет без пропусков по московским квартирам.
# ### Итог:
#  - файл data.csv, отвечающий критериям:
#             названия колонок на английском языке в одно/несколько слов с нижним подчёркиванием
#             в каждой колонке должны отсутствовать пропущенные значения (NaN, None и т.д.)
#  - ноутбук preprocessing.ipynb, где показан процесс обработки данных

# %%
# загружаем данные. 2 варианта с google диска или из локальной папки data и выодим на экран
# file_id = "130KYOX8O4wrP_T8vdz2GfvJRQ03ONmE7"
# path_data = f"https://drive.google.com/uc?export=download&id={file_id}"
path_data = r'../../data/_data.csv' # если не работает скачивание с google диска
data_df = pd.read_csv(path_data, encoding='utf-8', index_col=0)
data_df.head(5)
# Out:
#    ID  объявления Количество комнат       Тип                         Метро  \
# 0       271271157                 4  Квартира  м. Смоленская (9 мин пешком)
# 1       271634126                 4  Квартира  м. Смоленская (8 мин пешком)
# 2       271173086   4, Оба варианта  Квартира  м. Смоленская (7 мин пешком)
# 3       272197456   4, Оба варианта  Квартира  м. Смоленская (3 мин пешком)
# 4       273614615                 2  Квартира   м. Арбатская (7 мин пешком)
#
#                               Адрес      Площадь, м2  \
# 0     Москва, улица Новый Арбат, 27       200.0/20.0
# 1     Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2     Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3  Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4     Москва, улица Новый Арбат, 15    58.0/38.0/5.0
#
#                          Дом   Парковка  \
# 0           5/16, Монолитный  подземная
# 1  5/16, Монолитно-кирпичный  подземная
# 2                       5/16  подземная
# 3                        5/6  подземная
# 4           12/26, Панельный        NaN
#
#                                                 Цена  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 2  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 3  400000.0 руб./ За месяц, Залог - 400000 руб., ...
# 4  225000.0 руб./ За месяц, Залог - 225000 руб., ...
#
#                      Телефоны  \
# 0                +79166369231
# 1                +79850608590
# 2  +79672086536, +79099269384
# 3  +79660342340, +79099269384
# 4                +79852432860
#
#                                             Описание        Ремонт  \
# 0  Без комиссии для нанимателя! Бонус коллегам 12...  Дизайнерский
# 1  Лот 93107. Елена Анисимова.\n\nБонус агенту 50...  Дизайнерский
# 2  ID 36380:  Шикарная 4-х км. квартира в ЖК "Нов...    Евроремонт
# 3  ID 31618:  Эксклюзивное предложение. Современн...    Евроремонт
# 4  Лот 111542. Татьяна Лучкина.\n\nБонус агенту 5...    Евроремонт
#
#   Площадь комнат, м2 Балкон             Окна                          Санузел  \
# 0                NaN    NaN              NaN                              NaN
# 1        25 25 20 25    NaN  На улицу и двор  Совмещенный (2), Раздельный (1)
# 2                NaN    NaN  На улицу и двор                  Совмещенный (3)
# 3        14-42-20-19    NaN  На улицу и двор                  Совмещенный (3)
# 4              20 18    NaN  На улицу и двор                  Совмещенный (2)
#
#             Можно с детьми/животными  \
# 0  Можно с детьми, Можно с животными
# 1                     Можно с детьми
# 2                     Можно с детьми
# 3                  Можно с животными
# 4                                NaN
#
#                                        Дополнительно        Название ЖК  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...  Новый Арбат, 2010
# 1  Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 2  Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 3  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                NaN
# 4  Мебель в комнатах, Мебель на кухне, Ванна, Душ...           The Book
#
#   Серия дома  Высота потолков, м                Лифт Мусоропровод  \
# 0        NaN                 3.0  Пасс (4), Груз (1)           Да
# 1        NaN                 3.5  Пасс (1), Груз (1)          Нет
# 2        NaN                 3.2            Пасс (1)          NaN
# 3        NaN                 3.2            Пасс (1)          NaN
# 4        NaN                 3.9  Пасс (1), Груз (1)           Да
#
#                       Ссылка на объявление
# 0  https://www.cian.ru/rent/flat/271271157
# 1  https://www.cian.ru/rent/flat/271634126
# 2  https://www.cian.ru/rent/flat/271173086
# 3  https://www.cian.ru/rent/flat/272197456
# 4  https://www.cian.ru/rent/flat/273614615

# %%
# размер датафрейма
data_df.shape
# Out:
# (23368, 24)

# %%
# оставляем только Москву
data_df = data_df[data_df['Адрес'].str.upper().str.contains('МОСКВА', na=False)].copy()
data_df.shape
# Out:
# (19737, 24)

# %%
# выбираем пропущенные значения из датафрейма
pd.DataFrame((data_df.isna().mean() * 100) \
            .sort_values(ascending=False) \
            .round(2) \
            .reset_index()) \
            .rename(columns={
                    'index': 'Название столбца',
                    0: 'Процент пропусков, %'
})
# Out:
#             Название столбца  Процент пропусков, %
# 0                 Серия дома                 89.41
# 1                Название ЖК                 77.42
# 2                   Парковка                 56.61
# 3         Высота потолков, м                 46.62
# 4               Мусоропровод                 40.57
# 5         Площадь комнат, м2                 36.62
# 6                     Балкон                 33.59
# 7                       Окна                 26.09
# 8   Можно с детьми/животными                 24.90
# 9                       Лифт                 21.24
# 10                    Ремонт                 12.48
# 11                   Санузел                 10.34
# 12         Количество комнат                  2.71
# 13                     Метро                  1.75
# 14             Дополнительно                  1.38
# 15            ID  объявления                  0.00
# 16                       Дом                  0.00
# 17               Площадь, м2                  0.00
# 18                     Адрес                  0.00
# 19                       Тип                  0.00
# 20                  Телефоны                  0.00
# 21                      Цена                  0.00
# 22                  Описание                  0.00
# 23      Ссылка на объявление                  0.00

# %% [markdown]
# Удаляем неинфомативные колонки, а также столбцы с большим количество пропусков.
#
# К столбцам из предыдущего релиза(Серия дома, Название ЖК) добавим столбцы Телефоны, Ссылка на объявление, Тип, Площадь комнат, м2

# %%
# удаляем следующие колонки которые не несут ценности, или имеют количество пропусков (>70%)
col_drop = ['Серия дома', 'Название ЖК', 'Телефоны', 'Ссылка на объявление', 'Тип', 'Площадь комнат, м2']
data_df = data_df.drop(col_drop, axis=1)
data_df.shape
# Out:
# (19737, 18)

# %%
# статистика
data_df.describe(include='all')
# Out:
#         ID  объявления Количество комнат                             Метро  \
# count     1.973700e+04             19202                             19391
# unique             NaN                24                              4871
# top                NaN                 1  м. Водный стадион (5 мин пешком)
# freq               NaN              6646                                40
# mean      2.671149e+08               NaN                               NaN
# std       1.980106e+07               NaN                               NaN
# min       1.072986e+08               NaN                               NaN
# 25%       2.712212e+08               NaN                               NaN
# 50%       2.739284e+08               NaN                               NaN
# 75%       2.746973e+08               NaN                               NaN
# max       2.750064e+08               NaN                               NaN
#
#                                  Адрес     Площадь, м2             Дом  \
# count                            19737           19737           19737
# unique                           10452            9585            2415
# top     Москва, Чапаевский переулок, 3  40.0/20.0/10.0  3/5, Кирпичный
# freq                                63             214             265
# mean                               NaN             NaN             NaN
# std                                NaN             NaN             NaN
# min                                NaN             NaN             NaN
# 25%                                NaN             NaN             NaN
# 50%                                NaN             NaN             NaN
# 75%                                NaN             NaN             NaN
# max                                NaN             NaN             NaN
#
#         Парковка                                               Цена Описание  \
# count       8563                                              19737    19737
# unique         5                                               2219    19456
# top     наземная  40000.0 руб./ За месяц, Залог - 40000 руб., Ко...        0
# freq        5283                                               1112      108
# mean         NaN                                                NaN      NaN
# std          NaN                                                NaN      NaN
# min          NaN                                                NaN      NaN
# 25%          NaN                                                NaN      NaN
# 50%          NaN                                                NaN      NaN
# 75%          NaN                                                NaN      NaN
# max          NaN                                                NaN      NaN
#
#                Ремонт      Балкон     Окна          Санузел  \
# count           17274       13107    14587            17696
# unique              4          18        3               20
# top     Косметический  Балкон (1)  Во двор  Совмещенный (1)
# freq             7361        6336     9708             8500
# mean              NaN         NaN      NaN              NaN
# std               NaN         NaN      NaN              NaN
# min               NaN         NaN      NaN              NaN
# 25%               NaN         NaN      NaN              NaN
# 50%               NaN         NaN      NaN              NaN
# 75%               NaN         NaN      NaN              NaN
# max               NaN         NaN      NaN              NaN
#
#        Можно с детьми/животными  \
# count                     14822
# unique                        3
# top              Можно с детьми
# freq                       8540
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                             Дополнительно  Высота потолков, м  \
# count                                               19465        10535.000000
# unique                                                488                 NaN
# top     Мебель в комнатах, Мебель на кухне, Ванна, Сти...                 NaN
# freq                                                 2553                 NaN
# mean                                                  NaN            2.992925
# std                                                   NaN            7.852740
# min                                                   NaN            1.200000
# 25%                                                   NaN            2.640000
# 50%                                                   NaN            2.640000
# 75%                                                   NaN            2.800000
# max                                                   NaN          320.000000
#
#             Лифт Мусоропровод
# count      15545        11730
# unique        34            2
# top     Пасс (1)           Да
# freq        4865        10262
# mean         NaN          NaN
# std          NaN          NaN
# min          NaN          NaN
# 25%          NaN          NaN
# 50%          NaN          NaN
# 75%          NaN          NaN
# max          NaN          NaN

# %%
# выбираем пропущенные значения из датафрейма
pd.DataFrame((data_df.isna().mean() * 100) \
            .sort_values(ascending=False) \
            .round(2) \
            .reset_index()) \
            .rename(columns={
                    'index': 'Название столбца',
                    0: 'Процент пропусков, %'
})
# Out:
#             Название столбца  Процент пропусков, %
# 0                   Парковка                 56.61
# 1         Высота потолков, м                 46.62
# 2               Мусоропровод                 40.57
# 3                     Балкон                 33.59
# 4                       Окна                 26.09
# 5   Можно с детьми/животными                 24.90
# 6                       Лифт                 21.24
# 7                     Ремонт                 12.48
# 8                    Санузел                 10.34
# 9          Количество комнат                  2.71
# 10                     Метро                  1.75
# 11             Дополнительно                  1.38
# 12            ID  объявления                  0.00
# 13                  Описание                  0.00
# 14                     Адрес                  0.00
# 15                      Цена                  0.00
# 16               Площадь, м2                  0.00
# 17                       Дом                  0.00

# %% [markdown]
# 13 признаков имеют пропуски, из которых 3 имеют количество пропусков более 40% значений.
#
# Признак цена, в котором находится целевая переменная с купе с другой инфрмацией пропусков не имеет.
#
# Следовательно можно предположить, что выделить целевую переменную в релизе 3 возможно в 100%.
#
# Сложности по заполнению будут с полями, в которых отмечается значительное количество пропусков.
#
# Не все можно заполнить стандартными средствами (mean, median, mode, const). Нужно поизучать.
#
# `ID объявления` признак маркер, который не несет информации, но важен для определения цены другми подразделениями.

# %%
data_df.head()
# Out:
#    ID  объявления Количество комнат                         Метро  \
# 0       271271157                 4  м. Смоленская (9 мин пешком)
# 1       271634126                 4  м. Смоленская (8 мин пешком)
# 2       271173086   4, Оба варианта  м. Смоленская (7 мин пешком)
# 3       272197456   4, Оба варианта  м. Смоленская (3 мин пешком)
# 4       273614615                 2   м. Арбатская (7 мин пешком)
#
#                               Адрес      Площадь, м2  \
# 0     Москва, улица Новый Арбат, 27       200.0/20.0
# 1     Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2     Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3  Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4     Москва, улица Новый Арбат, 15    58.0/38.0/5.0
#
#                          Дом   Парковка  \
# 0           5/16, Монолитный  подземная
# 1  5/16, Монолитно-кирпичный  подземная
# 2                       5/16  подземная
# 3                        5/6  подземная
# 4           12/26, Панельный        NaN
#
#                                                 Цена  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 2  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 3  400000.0 руб./ За месяц, Залог - 400000 руб., ...
# 4  225000.0 руб./ За месяц, Залог - 225000 руб., ...
#
#                                             Описание        Ремонт Балкон  \
# 0  Без комиссии для нанимателя! Бонус коллегам 12...  Дизайнерский    NaN
# 1  Лот 93107. Елена Анисимова.\n\nБонус агенту 50...  Дизайнерский    NaN
# 2  ID 36380:  Шикарная 4-х км. квартира в ЖК "Нов...    Евроремонт    NaN
# 3  ID 31618:  Эксклюзивное предложение. Современн...    Евроремонт    NaN
# 4  Лот 111542. Татьяна Лучкина.\n\nБонус агенту 5...    Евроремонт    NaN
#
#               Окна                          Санузел  \
# 0              NaN                              NaN
# 1  На улицу и двор  Совмещенный (2), Раздельный (1)
# 2  На улицу и двор                  Совмещенный (3)
# 3  На улицу и двор                  Совмещенный (3)
# 4  На улицу и двор                  Совмещенный (2)
#
#             Можно с детьми/животными  \
# 0  Можно с детьми, Можно с животными
# 1                     Можно с детьми
# 2                     Можно с детьми
# 3                  Можно с животными
# 4                                NaN
#
#                                        Дополнительно  Высота потолков, м  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.0
# 1  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.5
# 2  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.2
# 3  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.2
# 4  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.9
#
#                  Лифт Мусоропровод
# 0  Пасс (4), Груз (1)           Да
# 1  Пасс (1), Груз (1)          Нет
# 2            Пасс (1)          NaN
# 3            Пасс (1)          NaN
# 4  Пасс (1), Груз (1)           Да

# %%
# выявим выбросы в высоте потолков, посмотрим количество
data_df[(data_df['Высота потолков, м'] < 2.4) | (data_df['Высота потолков, м'] > 8)]
# Out:
#        ID  объявления Количество комнат                               Метро  \
# 9           272900409                 4        м. Арбатская (10 мин пешком)
# 247         271203810                 1    м. Селигерская (None мин пешком)
# 2969        274867097                 3        м. Каширская (31 мин пешком)
# 3759        274982211  3, Изолированная    м. Домодедовская (20 мин пешком)
# 4072        252733003  2, Изолированная   м. Бабушкинская (6 мин на машине)
# 4126        240892098               NaN       м. Медведково (25 мин пешком)
# 6616        274903162               NaN      м. Авиамоторная (9 мин пешком)
# 7423        274946733                 1       м. Нагатинская (8 мин пешком)
# 7522        268545042   6, Оба варианта                                 NaN
# 8343        274453264                 2         м. Нагорная (12 мин пешком)
# 8382        166609594                 1      м. Чертановская (4 мин пешком)
# 8625        272179535                 6   м. Чистые пруды (6 мин на машине)
# 8832        232362985   2, Оба варианта         м. Крымская (14 мин пешком)
# 9280        274998351                 2         м. Каховская (9 мин пешком)
# 11076       272544152                 2  м. Бунинская аллея (13 мин пешком)
# 11123       271267183   2, Оба варианта       м. Новаторская (5 мин пешком)
# 11189       274140593                 2     м. Академическая (7 мин пешком)
# 12636       274906525  2, Изолированная       м. Парк Победы (6 мин пешком)
# 15769       219565783  2, Изолированная         м. Давыдково (9 мин пешком)
# 16345       272497594                 2      м. Измайловская (5 мин пешком)
# 17134       274849798                 1     м. Нижегородская (5 мин пешком)
# 21584       265857148                 1   м. Бабушкинская (3 мин на машине)
# 22070       273432181               NaN               м. ЗИЛ (5 мин пешком)
# 22265       274439221                 3    м. Менделеевская (15 мин пешком)
#
#                                                    Адрес       Площадь, м2  \
# 9                            Москва, улица Арбат, 30/3С1    90.0/66.0/10.0
# 247    Москва, Долгопрудная аллея, 14к1, ш. Дмитровск...    38.0/18.0/10.0
# 2969                      Москва, Каширский проезд, 25к1              82.4
# 3759                     Москва, Борисовский проезд, 8К2    58.0/42.0/10.0
# 4072                        Москва, Полярная улица, 27к4    44.0/30.0/10.0
# 4126                        Москва, Полярная улица, 27к2      18.9/8.2/4.7
# 6616              Москва, Красноказарменная улица, 14Ак1     21.0/14.0/2.0
# 7423                      Москва, Варшавское шоссе, 49к1     37.0/15.0/8.0
# 7522                         Москва, Каширское шоссе, 16             132.0
# 8343                       Москва, Криворожская улица, 1     41.0/26.0/6.0
# 8382                 Москва, Балаклавский проспект, 10К3     36.0/18.0/9.0
# 8625                     Москва, Мясницкая улица, 21/8с8  165.0/100.0/35.0
# 8832                      Москва, улица Винокурова, 22К2          47.0/7.0
# 9280                    Москва, Болотниковская улица, 30    53.0/30.5/12.0
# 11076  Москва, улица Академика Понтрягина, 27, ш. Кал...    51.0/33.0/10.0
# 11123                    Москва, Ленинский проспект, 95Б    52.0/30.0/13.0
# 11189                    Москва, Профсоюзная улица, 7/12    65.0/40.0/14.0
# 12636                       Москва, улица 1812 года, 8К2     60.0/38.0/8.0
# 15769                  Москва, Кременчугская улица, 40К1     40.6/25.0/5.5
# 16345                   Москва, Первомайская улица, 42к3    53.0/20.0/25.0
# 17134                  Москва, Нижегородская улица, 86кБ    42.0/22.0/10.0
# 21584                       Москва, улица Коминтерна, 15         40.4/17.3
# 22070                Москва, Автозаводская улица, 23С120     25.0/12.0/4.0
# 22265                    Москва, Октябрьский переулок, 9        116.0/30.0
#
#                               Дом        Парковка  \
# 9                 2/7, Сталинский        открытая
# 247                 3/14, Блочный             NaN
# 2969   12/22, Монолитно-кирпичный        наземная
# 3759               6/9, Панельный             NaN
# 4072    7/25, Монолитно-кирпичный        наземная
# 4126             7/15, Монолитный        наземная
# 6616            18/23, Монолитный       подземная
# 7423                 5/8, Блочный        наземная
# 7522               1/8, Кирпичный        наземная
# 8343               3/5, Кирпичный             NaN
# 8382              2/17, Панельный        наземная
# 8625               6/7, Кирпичный             NaN
# 8832               4/5, Кирпичный        наземная
# 9280              5/14, Панельный             NaN
# 11076             9/14, Панельный        наземная
# 11123           28/33, Монолитный       подземная
# 11189              9/9, Кирпичный        открытая
# 12636              8/8, Кирпичный             NaN
# 15769              2/5, Кирпичный        наземная
# 16345           21/28, Монолитный       подземная
# 17134  11/17, Монолитно-кирпичный        наземная
# 21584           15/20, Монолитный        наземная
# 22070                        8/13  многоуровневая
# 22265            3/13, Монолитный             NaN
#
#                                                     Цена  \
# 9      210000.0 руб./ За месяц, Залог - 210000 руб., ...
# 247    32000.0 руб./ За месяц, Залог - 32000 руб., Ко...
# 2969   65000.0 руб./ За месяц, Залог - 75000 руб., Ко...
# 3759   45000.0 руб./ За месяц, Залог - 45000 руб., Ср...
# 4072   44000.0 руб./ За месяц, Залог - 44000 руб., Ко...
# 4126   40000.0 руб./ За месяц, Залог - 40000 руб., Ко...
# 6616   48000.0 руб./ За месяц, Залог - 48000 руб., Ко...
# 7423   45000.0 руб./ За месяц, Залог - 45000 руб., Ко...
# 7522   149999.0 руб./ За месяц, Залог - 149999 руб., ...
# 8343   45000.0 руб./ За месяц, Залог - 45000 руб., Ко...
# 8382   40000.0 руб./ За месяц, Залог - 40000 руб., Ко...
# 8625   230000.0 руб./ За месяц, Залог - 230000 руб., ...
# 8832   55000.0 руб./ За месяц, Залог - 30000 руб., Ко...
# 9280   50000.0 руб./ За месяц, Залог - 50000 руб., Ср...
# 11076  40000.0 руб./ За месяц, Залог - 40000 руб., Ко...
# 11123  140000.0 руб./ За месяц, Залог - 140000 руб., ...
# 11189  75000.0 руб./ За месяц, Залог - 75000 руб., Ко...
# 12636  68000.0 руб./ За месяц, Залог - 65000 руб., Ср...
# 15769  50000.0 руб./ За месяц, Залог - 50000 руб., Ко...
# 16345  65000.0 руб./ За месяц, Залог - 65000 руб., Ко...
# 17134  45000.0 руб./ За месяц, Залог - 45000 руб., Ср...
# 21584  60000.0 руб./ За месяц, Залог - 60000 руб., Ко...
# 22070  45000.0 руб./ За месяц, Залог - 45000 руб., Ко...
# 22265  165000.0 руб./ За месяц, Залог - 165000 руб., ...
#
#                                                 Описание         Ремонт  \
# 9      Лот 102641. Эдуард Кочергин.\n\nБонус агенту 2...     Евроремонт
# 247    Срочно! Сдам однокомнатную квартиру после ремо...  Косметический
# 2969   Читаем до конца, в услугах агентов не нуждаюсь...     Евроремонт
# 3759   Оперативно сдается уютная 3-комнатная квартира...  Косметический
# 4072   ЕВРОДВУШКА = с кухней переходящей в гостиную, ...     Евроремонт
# 4126   Студия в новом доме. Возможна сдача от года. В...  Косметический
# 6616   Сдается впервые! Новая мебель и бытовая техник...  Косметический
# 7423   Вашему вниманию представлена 1-комнатная кварт...     Евроремонт
# 7522   Долгосрочно сдается в аренду от собственника н...   Дизайнерский
# 8343   Предлагается теплая двухкомнатная квартира нед...            NaN
# 8382   Сдается с качественным ремонтом уютная квартир...  Косметический
# 8625   БЕЗ КОМИССИИ ДЛЯ АРЕНДАТОРА. Просторная 6-ти к...            NaN
# 8832   Квартира с интересным панировочным решением и ...     Евроремонт
# 9280   Сдается светлая просторная двухкомнатная кварт...  Косметический
# 11076  Предлагается двухкомнатная квартира в пешей до...            NaN
# 11123  ЖК "The MID". Бонус агенту 15 000 рублей, выда...   Дизайнерский
# 11189  Лот 98254. Ирина Волкова.\n\nБез комиссии для ...  Косметический
# 12636  Сдаётся 2-х комнатная квартира со всей необход...     Евроремонт
# 15769  Сдаётся уютная 2-х комнатная квартира в ЗАО с ...     Евроремонт
# 16345  Сдаём 1-комнатную квартиру (кухня с гостиной и...     Евроремонт
# 17134  Шикарное предложение в кирпично-монолитном дом...     Евроремонт
# 21584  Видовая однокомнатная квартира на 15 этаже в н...     Евроремонт
# 22070  Предложение без комиссии.\n\nСтудия Д\n\nАпарт...   Дизайнерский
# 22265  Предлагается в аренду просторная квартира 116 ...   Дизайнерский
#
#                        Балкон             Окна  \
# 9                  Балкон (1)  На улицу и двор
# 247                Балкон (1)  На улицу и двор
# 2969               Лоджия (1)         На улицу
# 3759               Лоджия (1)  На улицу и двор
# 4072                      NaN          Во двор
# 4126                      NaN         На улицу
# 6616                      NaN          Во двор
# 7423               Балкон (1)         На улицу
# 7522   Балкон (1), Лоджия (1)         На улицу
# 8343               Балкон (1)         На улицу
# 8382               Балкон (1)         На улицу
# 8625                      NaN              NaN
# 8832               Балкон (1)          Во двор
# 9280               Лоджия (2)  На улицу и двор
# 11076              Балкон (1)         На улицу
# 11123                     NaN          Во двор
# 11189              Балкон (1)          Во двор
# 12636                     NaN         На улицу
# 15769              Балкон (1)  На улицу и двор
# 16345                     NaN  На улицу и двор
# 17134              Балкон (1)              NaN
# 21584              Лоджия (1)         На улицу
# 22070                     NaN          Во двор
# 22265              Балкон (1)  На улицу и двор
#
#                                Санузел           Можно с детьми/животными  \
# 9      Совмещенный (1), Раздельный (1)                     Можно с детьми
# 247                                NaN  Можно с детьми, Можно с животными
# 2969                   Совмещенный (2)                     Можно с детьми
# 3759                    Раздельный (1)                     Можно с детьми
# 4072                   Совмещенный (1)                                NaN
# 4126                   Совмещенный (1)                                NaN
# 6616                   Совмещенный (1)                                NaN
# 7423                   Совмещенный (1)                     Можно с детьми
# 7522                    Раздельный (2)  Можно с детьми, Можно с животными
# 8343                    Раздельный (1)  Можно с детьми, Можно с животными
# 8382                   Совмещенный (1)                                NaN
# 8625   Совмещенный (1), Раздельный (1)                     Можно с детьми
# 8832                   Совмещенный (1)                     Можно с детьми
# 9280                    Раздельный (1)                                NaN
# 11076                   Раздельный (1)                     Можно с детьми
# 11123                  Совмещенный (1)  Можно с детьми, Можно с животными
# 11189                   Раздельный (1)  Можно с детьми, Можно с животными
# 12636                  Совмещенный (1)  Можно с детьми, Можно с животными
# 15769                  Совмещенный (1)                     Можно с детьми
# 16345                  Совмещенный (1)                                NaN
# 17134                  Совмещенный (1)                     Можно с детьми
# 21584                   Раздельный (1)                     Можно с детьми
# 22070                  Совмещенный (1)                                NaN
# 22265                   Раздельный (2)  Можно с детьми, Можно с животными
#
#                                            Дополнительно  Высота потолков, м  \
# 9      Мебель в комнатах, Мебель на кухне, Ванна, Сти...               310.0
# 247    Мебель в комнатах, Мебель на кухне, Ванна, Сти...               260.0
# 2969   Мебель в комнатах, Мебель на кухне, Ванна, Душ...                28.0
# 3759   Мебель в комнатах, Мебель на кухне, Стиральная...               264.0
# 4072   Мебель в комнатах, Мебель на кухне, Ванна, Сти...                27.0
# 4126   Мебель в комнатах, Мебель на кухне, Душевая ка...                 2.3
# 6616   Мебель в комнатах, Мебель на кухне, Душевая ка...                12.8
# 7423   Мебель в комнатах, Мебель на кухне, Ванна, Сти...                26.0
# 7522   Мебель в комнатах, Мебель на кухне, Душевая ка...                 2.3
# 8343     Ванна, Стиральная машина, Кондиционер, Интернет                 2.3
# 8382   Мебель в комнатах, Мебель на кухне, Душевая ка...                27.0
# 8625   Мебель в комнатах, Мебель на кухне, Стиральная...               320.0
# 8832   Мебель в комнатах, Мебель на кухне, Душевая ка...                28.0
# 9280                  Мебель в комнатах, Мебель на кухне               265.0
# 11076  Мебель в комнатах, Ванна, Стиральная машина, К...                 2.0
# 11123  Мебель в комнатах, Мебель на кухне, Душевая ка...                27.0
# 11189  Мебель в комнатах, Мебель на кухне, Ванна, Сти...               320.0
# 12636  Мебель в комнатах, Мебель на кухне, Ванна, Душ...               264.0
# 15769  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                25.0
# 16345  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                 2.1
# 17134  Мебель в комнатах, Мебель на кухне, Стиральная...               280.0
# 21584  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                28.0
# 22070  Мебель в комнатах, Мебель на кухне, Душевая ка...                27.0
# 22265  Мебель в комнатах, Мебель на кухне, Стиральная...                 1.2
#
#                      Лифт Мусоропровод
# 9                Пасс (1)           Да
# 247    Пасс (1), Груз (1)          NaN
# 2969   Пасс (2), Груз (1)          Нет
# 3759             Пасс (1)          NaN
# 4072   Пасс (1), Груз (2)          NaN
# 4126   Пасс (1), Груз (1)          Нет
# 6616             Пасс (1)          NaN
# 7423             Пасс (1)           Да
# 7522                  NaN          Нет
# 8343                  NaN          NaN
# 8382   Пасс (1), Груз (1)           Да
# 8625             Пасс (1)          NaN
# 8832                  NaN          NaN
# 9280                  NaN          NaN
# 11076  Пасс (1), Груз (1)          NaN
# 11123  Пасс (2), Груз (2)          NaN
# 11189            Пасс (1)           Да
# 12636            Пасс (1)           Да
# 15769                 NaN          Нет
# 16345  Пасс (3), Груз (1)           Да
# 17134  Пасс (1), Груз (1)          NaN
# 21584  Пасс (1), Груз (1)          NaN
# 22070  Пасс (2), Груз (2)          NaN
# 22265            Пасс (1)          NaN

# %% [markdown]
# Обычно высота квартир в пределах от 2.4 м (возможно до 2.1 с учетом перепланировки) и до 7.5 метров. Берем интервал высоты потолка от 2.0 по 8.0. Все остальное неверно и подлежит замене.
# Проверка высоты потолков в сети интернет показала, что значения:
# - больше 200, это высота в сантиметрах(нужно разделить на 100)
# - значения больше 20, но меньше 100 это высота деленая на 10 (вероятно забыли поставить точку)
# - значения менее 2х невозможны или это исключения, которые единичны и не представляют ценности.

# %%
data_df.head(6)
# Out:
#    ID  объявления Количество комнат                         Метро  \
# 0       271271157                 4  м. Смоленская (9 мин пешком)
# 1       271634126                 4  м. Смоленская (8 мин пешком)
# 2       271173086   4, Оба варианта  м. Смоленская (7 мин пешком)
# 3       272197456   4, Оба варианта  м. Смоленская (3 мин пешком)
# 4       273614615                 2   м. Арбатская (7 мин пешком)
# 5       274837728                 3  м. Смоленская (5 мин пешком)
#
#                                  Адрес      Площадь, м2  \
# 0        Москва, улица Новый Арбат, 27       200.0/20.0
# 1        Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2        Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3     Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4        Москва, улица Новый Арбат, 15    58.0/38.0/5.0
# 5  Москва, 1-й Смоленский переулок, 21             92.0
#
#                          Дом   Парковка  \
# 0           5/16, Монолитный  подземная
# 1  5/16, Монолитно-кирпичный  подземная
# 2                       5/16  подземная
# 3                        5/6  подземная
# 4           12/26, Панельный        NaN
# 5                        3/7        NaN
#
#                                                 Цена  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 2  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 3  400000.0 руб./ За месяц, Залог - 400000 руб., ...
# 4  225000.0 руб./ За месяц, Залог - 225000 руб., ...
# 5  470000.0 руб./ За месяц, Залог - 470000 руб., ...
#
#                                             Описание        Ремонт Балкон  \
# 0  Без комиссии для нанимателя! Бонус коллегам 12...  Дизайнерский    NaN
# 1  Лот 93107. Елена Анисимова.\n\nБонус агенту 50...  Дизайнерский    NaN
# 2  ID 36380:  Шикарная 4-х км. квартира в ЖК "Нов...    Евроремонт    NaN
# 3  ID 31618:  Эксклюзивное предложение. Современн...    Евроремонт    NaN
# 4  Лот 111542. Татьяна Лучкина.\n\nБонус агенту 5...    Евроремонт    NaN
# 5  ID 743. С коллегами работаем 50/50. Видовые ап...  Дизайнерский    NaN
#
#               Окна                          Санузел  \
# 0              NaN                              NaN
# 1  На улицу и двор  Совмещенный (2), Раздельный (1)
# 2  На улицу и двор                  Совмещенный (3)
# 3  На улицу и двор                  Совмещенный (3)
# 4  На улицу и двор                  Совмещенный (2)
# 5              NaN                              NaN
#
#             Можно с детьми/животными  \
# 0  Можно с детьми, Можно с животными
# 1                     Можно с детьми
# 2                     Можно с детьми
# 3                  Можно с животными
# 4                                NaN
# 5                                NaN
#
#                                        Дополнительно  Высота потолков, м  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.0
# 1  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.5
# 2  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.2
# 3  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.2
# 4  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.9
# 5  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 NaN
#
#                  Лифт Мусоропровод
# 0  Пасс (4), Груз (1)           Да
# 1  Пасс (1), Груз (1)          Нет
# 2            Пасс (1)          NaN
# 3            Пасс (1)          NaN
# 4  Пасс (1), Груз (1)           Да
# 5                 NaN          NaN

# %%
# удаляем выбросы
def height_room(x):
    if pd.isna(x):
        return x
    if x > 200:
        x /= 100
    if x > 22:
        x /= 10
    # Можно добавить проверку разумных границ
    if x < 2.0 or x > 8:  # например, всё вне [2.0, 6.0] — ошибка
        return np.nan  # или медиана, или None для последующей замены
    return x

data_df['Высота потолков, м'] = data_df['Высота потолков, м'].apply(height_room)
data_df[(data_df['Высота потолков, м'] < 2) | (data_df['Высота потолков, м'] > 8)]
# Out:
# Empty DataFrame
# Columns: [ID  объявления, Количество комнат, Метро, Адрес, Площадь, м2, Дом, Парковка, Цена, Описание, Ремонт, Балкон, Окна, Санузел, Можно с детьми/животными, Дополнительно, Высота потолков, м, Лифт, Мусоропровод]
# Index: []

# %%
# заполняем nan
def get_address(addr):
    if pd.isna(addr):
        return None
    addr_split = addr.split(',', maxsplit=3)
    if len(addr_split) >= 3:
        street = addr_split[1].strip()
        house = addr_split[2].strip()
        return f"{street}, {house}"
    else:
        return None

print(f"Доля пропусков  Высота потолков, м - {data_df['Высота потолков, м'].isna().mean() * 100}%")
# Применяем
data_df['address_tmp'] = data_df['Адрес'].apply(get_address)

data_df['Высота потолков, м'] = data_df.groupby('address_tmp')['Высота потолков, м'].transform(
    lambda x: x.fillna(x.median())
)
# выбираем пропущенные значения из датафрейма
print(f"Доля пропусков  Высота потолков, м - {data_df['Высота потолков, м'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Высота потолков, м - 46.63322693418452%
# Доля пропусков  Высота потолков, м - 23.711810305517556%

# %%
data_df.head(2)
# Out:
#    ID  объявления Количество комнат                         Метро  \
# 0       271271157                 4  м. Смоленская (9 мин пешком)
# 1       271634126                 4  м. Смоленская (8 мин пешком)
#
#                            Адрес      Площадь, м2                        Дом  \
# 0  Москва, улица Новый Арбат, 27       200.0/20.0           5/16, Монолитный
# 1  Москва, улица Новый Арбат, 27  198.0/95.0/18.0  5/16, Монолитно-кирпичный
#
#     Парковка                                               Цена  \
# 0  подземная  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1  подземная  500000.0 руб./ За месяц, Залог - 500000 руб., ...
#
#                                             Описание        Ремонт Балкон  \
# 0  Без комиссии для нанимателя! Бонус коллегам 12...  Дизайнерский    NaN
# 1  Лот 93107. Елена Анисимова.\n\nБонус агенту 50...  Дизайнерский    NaN
#
#               Окна                          Санузел  \
# 0              NaN                              NaN
# 1  На улицу и двор  Совмещенный (2), Раздельный (1)
#
#             Можно с детьми/животными  \
# 0  Можно с детьми, Можно с животными
# 1                     Можно с детьми
#
#                                        Дополнительно  Высота потолков, м  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.0
# 1  Мебель в комнатах, Мебель на кухне, Ванна, Душ...                 3.5
#
#                  Лифт Мусоропровод            address_tmp
# 0  Пасс (4), Груз (1)           Да  улица Новый Арбат, 27
# 1  Пасс (1), Груз (1)          Нет  улица Новый Арбат, 27

# %% [markdown]
# Удалось корректно заполнить 23% пропусков по высоте
# Остальное заполним медианой. Для реального проекта можно было бы еще выделить улицу, тип дома, серию дома.

# %%
# заполняем оставшиеся nan высоты медианой
print(f"Доля пропусков  Высота потолков, м - {data_df['Высота потолков, м'].isna().mean() * 100}%")
data_df['Высота потолков, м'].fillna(data_df['Высота потолков, м'].median(), inplace=True)
print(f"Доля пропусков  Высота потолков, м - {data_df['Высота потолков, м'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Высота потолков, м - 23.711810305517556%
# Доля пропусков  Высота потолков, м - 0.0%

# %%
print(f"Доля пропусков  Парковка - {data_df['Парковка'].isna().mean() * 100}%")
data_df['Парковка'] = data_df.groupby('address_tmp')['Парковка'].transform(
    lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else 'не указано')
)
print(f"Доля пропусков  Парковка - {data_df['Парковка'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Парковка - 56.61448041749%
# Доля пропусков  Парковка - 0.0%

# %% [markdown]
# Признак Мусоропровод заполняем  по адресу модой, если такого адреса нет, то ставим не указано. Можно использовать моду, но количество пропусков значительно, а у Мусоропровода есть как плюсы так и минусы.

# %%
data_df['Мусоропровод'].value_counts(normalize=True, dropna=False)
# Out:
# Мусоропровод
# Да     0.519937
# NaN    0.405685
# Нет    0.074378
# Name: proportion, dtype: float64

# %% [markdown]
# 40% пропусков это много, чтобы заполнить модой

# %%
print(f"Доля пропусков  Мусоропровод - {data_df['Мусоропровод'].isna().mean() * 100}%")
data_df['Мусоропровод'] = data_df.groupby('address_tmp')['Мусоропровод'].transform(
    lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else 'не указано')
)
print(f"Доля пропусков  Мусоропровод - {data_df['Мусоропровод'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Мусоропровод - 40.56847545219638%
# Доля пропусков  Мусоропровод - 0.0%

# %% [markdown]
# Отработка балконов по аналогии с предыдущими, если есть информация по адресу, то ставим моду по ней, если нет, то общую моду

# %%
def get_balkon(bal_tmp):
    mode_bal = bal_tmp.mode()
    if not mode_bal.empty:
        return bal_tmp.fillna(mode_bal.iloc[0])
    else:
        return bal_tmp.fillna('нет информации')

print(f"Доля пропусков  Балкон - {data_df['Балкон'].isna().mean() * 100}%")
data_df['Балкон'] = data_df.groupby('address_tmp')['Балкон'].transform(get_balkon)
print(f"Доля пропусков  Балкон - {data_df['Балкон'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Балкон - 33.59173126614987%
# Доля пропусков  Балкон - 0.0%

# %% [markdown]
# для корректного заполнения пропусков в количестве комнат и площади необходимо извлечь взаимно числовые значения для этих признаков.
# и после по количеству комнат можно медианой заполнить площадь, а по площади  определить количество комнат
# для заполнения площади:
# - использовать группировку адрес + площадь квартир и взять медианное значение количества комнат округлив до целого, по остальным сгруппировать по площади и взять медианное значение

# %%
#  выделение площади
def get_area_rent(text):
    if pd.isna(text) or str(text).strip() == '':
        return np.nan
    area_get = str(text).strip().split('/')[0]
    if area_get:
        try:
            return float(area_get)
        except:
            return np.nan
    return np.nan

data_df['area_tmp'] = data_df['Площадь, м2'].apply(get_area_rent)

# %%
#  выделение количества комнат
def get_cnt_room_rent(text):
    if pd.isna(text) or str(text).strip() == '':
        return np.nan
    cnt_room_get = str(text).strip().split(',')[0]
    if cnt_room_get:
        try:
            return float(cnt_room_get)
        except:
            return np.nan
    return np.nan

data_df['count_room'] = data_df['Количество комнат'].apply(get_cnt_room_rent)

# %%
data_df['count_room'] = data_df['Количество комнат'].apply(get_cnt_room_rent)

# %%
# заполнение количества комнат
print(f"Доля пропусков  Количество комнат - {data_df['Количество комнат'].isna().mean() * 100}%")
# заполняем по address + area_tmp
medians1 = data_df.groupby(['address_tmp', 'area_tmp'])['count_room'].transform('median')
mask1 = data_df['Количество комнат'].isna()
data_df.loc[mask1, 'Количество комнат'] = medians1[mask1].astype(str)

print(f"Доля пропусков  Количество комнат - {data_df['Количество комнат'].isna().mean() * 100}%")

# заполняем по area_tmp
medians2 = data_df.groupby('area_tmp')['count_room'].transform('median')
mask2 = data_df['Количество комнат'].isna()
data_df.loc[mask2, 'Количество комнат'] = medians2[mask2].astype(str)

print(f"Доля пропусков  Количество комнат - {data_df['Количество комнат'].isna().mean() * 100}%")
# глобальная медиана
global_median = data_df['count_room'].median()
mask3 = data_df['Количество комнат'].isna()
data_df.loc[mask3, 'Количество комнат'] = str(global_median)
print(f"Доля пропусков  Количество комнат - {data_df['Количество комнат'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Количество комнат - 2.7106449815068148%
# Доля пропусков  Количество комнат - 0.0%
# Доля пропусков  Количество комнат - 0.0%
# Доля пропусков  Количество комнат - 0.0%

# %%
# заполним столбец полными значениями для использования далее
data_df['count_room'] = data_df['Количество комнат'].apply(get_cnt_room_rent)

# %% [markdown]
# Признак ремонт заполним значением не указано. Невозможно предположить какой ремонт в наличии.

# %%
print(f"Доля пропусков  Ремонт - {data_df['Ремонт'].isna().mean() * 100}%")
data_df['Ремонт'] = data_df['Ремонт'].fillna('не указано')
print(f"Доля пропусков  Ремонт - {data_df['Ремонт'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Ремонт - 12.479100167198661%
# Доля пропусков  Ремонт - 0.0%

# %% [markdown]
# Признак лифт группировкой по адресу + заполнить модой, остальное заполнить просто Пасс (1), лифт есть практически во всех домах в Москве, кроме 5этажек старых.

# %%
def get_lift_by_address(lift_val):
    mode_val = lift_val.mode()
    if not mode_val.empty:
        return lift_val.fillna(mode_val.iloc[0])
    else:
        return lift_val

print(f"Доля пропусков  Лифт - {data_df['Лифт'].isna().mean() * 100}%")
# Заполняем по адресу
data_df['Лифт'] = data_df.groupby('address_tmp')['Лифт'].transform(get_lift_by_address)
print(f"Доля пропусков  Лифт - {data_df['Лифт'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Лифт - 21.23929675229265%
# Доля пропусков  Лифт - 13.193494452044382%

# %%
# Оставшиеся NaN заполняем значением не указано и в Релизе 3 можем с ними поработать
print(f"Доля пропусков  Лифт - {data_df['Лифт'].isna().mean() * 100}%")
data_df['Лифт'] = data_df['Лифт'].fillna('не указано')   
print(f"Доля пропусков  Лифт - {data_df['Лифт'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Лифт - 13.193494452044382%
# Доля пропусков  Лифт - 0.0%

# %% [markdown]
# по лифтам есть работа для Релиза 3, для этажей <= 5 установить что лифта нет, для > 5 что есть

# %% [markdown]
# для корректного заполнения пропусков в признаке санузел.
# - использовать группировку адрес + количество комнат и взять моду, по остальным сгруппировать по количеству комнат и взять моду

# %%
def get_san(san_val):
    mode_val = san_val.mode()
    if not mode_val.empty:
        return san_val.fillna(mode_val.iloc[0])
    return san_val

print(f"Доля пропусков  Санузел - {data_df['Санузел'].isna().mean() * 100}%")
# Заполняем по адресу + количеству комнат
data_df['Санузел'] = data_df.groupby(['address_tmp', 'count_room'])['Санузел'].transform(get_san)

# Заполняем по количеству комнат
data_df['Санузел'] = data_df.groupby('count_room')['Санузел'].transform(get_san)
print(f"Доля пропусков  Санузел - {data_df['Санузел'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Санузел - 10.340983938795157%
# Доля пропусков  Санузел - 1.9759841921264631%

# %% [markdown]
# остальное заполняем значением есть. В Москве предполагается наличие санузла в квартирах.

# %%
data_df['Санузел'] = data_df['Санузел'].fillna('есть')
print(f"Доля пропусков  Санузел - {data_df['Санузел'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Санузел - 0.0%

# %% [markdown]
# Признак Можно с детьми/животными заполняем не указано. Так как это индивидуальное пожелание арендодателя.

# %%
print(f"Доля пропусков  Можно с детьми/животными - {data_df['Можно с детьми/животными'].isna().mean() * 100}%")
data_df['Можно с детьми/животными'] = data_df['Можно с детьми/животными'].fillna('не указано')
print(f"Доля пропусков  Можно с детьми/животными - {data_df['Можно с детьми/животными'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Можно с детьми/животными - 24.90246744692709%
# Доля пропусков  Можно с детьми/животными - 0.0%

# %% [markdown]
# Для запонения признака Окна логично использовать группировку адрес + количество комнат и заполнить модой, остальное сгруппировать по количеству комнат и заполнить модой

# %%
def get_wind(wind_val):
    mode_val = wind_val.mode()
    if not mode_val.empty:
        return wind_val.fillna(mode_val.iloc[0])
    return wind_val

print(f"Доля пропусков  Окна - {data_df['Окна'].isna().mean() * 100}%")
# Заполняем по адресу + количеству комнат
data_df['Окна'] = data_df.groupby(['address_tmp', 'count_room'])['Окна'].transform(get_wind)

# Заполняем по количеству комнат
data_df['Окна'] = data_df.groupby('count_room')['Окна'].transform(get_wind)
print(f"Доля пропусков  Окна - {data_df['Окна'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Окна - 26.093124588336625%
# Доля пропусков  Окна - 1.9810508182601205%

# %%
def get_wind(wind_val):
    mode_val = wind_val.mode()
    if not mode_val.empty:
        return wind_val.fillna(mode_val.iloc[0])
    return wind_val

print(f"Доля пропусков  Окна - {data_df['Окна'].isna().mean() * 100}%")
# Заполняем по адресу + площадь
data_df['Окна'] = data_df.groupby(['address_tmp', 'area_tmp'])['Окна'].transform(get_wind)

# Заполняем по площади
data_df['Окна'] = data_df.groupby('area_tmp')['Окна'].transform(get_wind)
print(f"Доля пропусков  Окна - {data_df['Окна'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Окна - 1.9810508182601205%
# Доля пропусков  Окна - 0.17733191467801593%

# %%
# Оставшиеся NaN заполняем значением не указано
print(f"Доля пропусков  Окна - {data_df['Окна'].isna().mean() * 100}%")
data_df['Окна'] = data_df['Окна'].fillna('не указано')   
print(f"Доля пропусков  Окна - {data_df['Окна'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Окна - 0.17733191467801593%
# Доля пропусков  Окна - 0.0%

# %% [markdown]
# признак метро заполнить группировкой по адресу и взять моду. по остальным проставить не указано и поработать в релизе 3

# %%
def get_metro(metro_val):
    mode_val = metro_val.mode()
    if not mode_val.empty:
        return metro_val.fillna(mode_val.iloc[0])
    return metro_val

print(f"Доля пропусков  Метро - {data_df['Метро'].isna().mean() * 100}%")
# Заполняем по количеству комнат
data_df['Метро'] = data_df.groupby('address_tmp')['Метро'].transform(get_metro)
print(f"Доля пропусков  Метро - {data_df['Метро'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Метро - 1.7530526422455288%
# Доля пропусков  Метро - 1.008258600597862%

# %%
# Оставшиеся NaN заполняем значением не указано и проработаем в Релизе 3
print(f"Доля пропусков  Метро - {data_df['Метро'].isna().mean() * 100}%")
data_df['Метро'] = data_df['Метро'].fillna('не указано')   
print(f"Доля пропусков  Метро - {data_df['Метро'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Метро - 1.008258600597862%
# Доля пропусков  Метро - 0.0%

# %% [markdown]
# Для признака Дополнительно использовать группировку ремонт + количество комнат, втак как для квартир дизайнерского ремонта будет схожее наполнение, как и для евро ремонта, если остались пропуски только ремонт

# %%
def get_dop(val):
    mode_val = val.mode()
    if not mode_val.empty:
        return val.fillna(mode_val.iloc[0])
    return val

print(f"Доля пропусков  Дополнительно - {data_df['Дополнительно'].isna().mean() * 100}%")
# По ремонту + количеству комнат
data_df['Дополнительно'] = data_df.groupby(['Ремонт', 'count_room'])['Дополнительно'].transform(get_dop)

# По типу ремонта
data_df['Дополнительно'] = data_df.groupby('Ремонт')['Дополнительно'].transform(get_dop)

print(f"Доля пропусков  Дополнительно - {data_df['Дополнительно'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Дополнительно - 1.3781223083548666%
# Доля пропусков  Дополнительно - 0.0%

# %%
print(f"Доля пропусков  Дополнительно - {data_df['Дополнительно'].isna().mean() * 100}%")
# Остатки — 'не указано'
data_df['Дополнительно'] = data_df['Дополнительно'].fillna('не указано')
print(f"Доля пропусков  Дополнительно - {data_df['Дополнительно'].isna().mean() * 100}%")
# Out:
# Доля пропусков  Дополнительно - 0.0%
# Доля пропусков  Дополнительно - 0.0%

# %% [markdown]
# Признак Площадь комнат, м2 несет информацию, подобную признаку Площадь, м2, при это имеет 36% пропусков

# %%
# def get_area_room(val):
#     mode_val = val.mode()
#     if not mode_val.empty:
#         return val.fillna(mode_val.iloc[0])
#     return val

# print(f"Доля пропусков  Площадь комнат, м2 - {data_df['Площадь комнат, м2'].isna().mean() * 100}%")
# # Заполняем по адресу + количеству комнат
# data_df['Площадь комнат, м2'] = data_df.groupby(['address_tmp', 'count_room'])['Площадь комнат, м2'].transform(get_area_room)

# # Заполняем по количеству комнат
# data_df['Площадь комнат, м2'] = data_df.groupby('count_room')['Площадь комнат, м2'].transform(get_area_room)
# print(f"Доля пропусков  Площадь комнат, м2 - {data_df['Площадь комнат, м2'].isna().mean() * 100}%")

# %%
# def get_area_room2(wind_val):
#     mode_val = wind_val.mode()
#     if not mode_val.empty:
#         return wind_val.fillna(mode_val.iloc[0])
#     return wind_val

# print(f"Доля пропусков  Площадь комнат, м2 - {data_df['Площадь комнат, м2'].isna().mean() * 100}%")
# # Заполняем по адресу + количеству комнат
# data_df['Площадь комнат, м2'] = data_df.groupby(['address_tmp', 'area_tmp'])['Площадь комнат, м2'].transform(get_area_room2)

# # Заполняем по количеству комнат
# data_df['Площадь комнат, м2'] = data_df.groupby('area_tmp')['Площадь комнат, м2'].transform(get_area_room2)
# print(f"Доля пропусков  Площадь комнат, м2 - {data_df['Площадь комнат, м2'].isna().mean() * 100}%")

# %%
data_df.columns
# Out:
# Index(['ID  объявления', 'Количество комнат', 'Метро', 'Адрес', 'Площадь, м2',
#        'Дом', 'Парковка', 'Цена', 'Описание', 'Ремонт', 'Балкон', 'Окна',
#        'Санузел', 'Можно с детьми/животными', 'Дополнительно',
#        'Высота потолков, м', 'Лифт', 'Мусоропровод', 'address_tmp', 'area_tmp',
#        'count_room'],
#       dtype='object')

# %% [markdown]
# удаляем временные столбцы data_df = data_df.drop(['house_address', 'area', 'rooms_count'], axis = 1)

# %%
data_df = data_df.drop(['address_tmp', 'area_tmp', 'count_room'], axis = 1)

# %%
data_df.columns
# Out:
# Index(['ID  объявления', 'Количество комнат', 'Метро', 'Адрес', 'Площадь, м2',
#        'Дом', 'Парковка', 'Цена', 'Описание', 'Ремонт', 'Балкон', 'Окна',
#        'Санузел', 'Можно с детьми/животными', 'Дополнительно',
#        'Высота потолков, м', 'Лифт', 'Мусоропровод'],
#       dtype='object')

# %%
def make_rus_lat(text):
    text = translit(text, 'ru', reversed=True)
    text = re.sub(r'[^\w\s]', '', text)
    text = '_'.join(text.split())
    return text

data_df.columns = [make_rus_lat(col).lower() for col in data_df.columns]

# %%
data_df.columns
# Out:
# Index(['id_objavlenija', 'kolichestvo_komnat', 'metro', 'adres', 'ploschad_m2',
#        'dom', 'parkovka', 'tsena', 'opisanie', 'remont', 'balkon', 'okna',
#        'sanuzel', 'mozhno_s_detmizhivotnymi', 'dopolnitelno',
#        'vysota_potolkov_m', 'lift', 'musoroprovod'],
#       dtype='object')

# %%
new_name_col = [
    'ad_id',
    'rooms',
    'metro',
    'address',
    'total_area',
    'building_type',
    'parking',
    'price',
    'description',
    'renovation_type',
    'balcony',
    'windows_view',
    'bathroom_type',
    'pets_allowed',
    'amenities',
    'ceiling_height',
    'elevator',
    'garbage_chute'
]

# %%
data_df.columns = new_name_col

# %%
data_df.columns
# Out:
# Index(['ad_id', 'rooms', 'metro', 'address', 'total_area', 'building_type',
#        'parking', 'price', 'description', 'renovation_type', 'balcony',
#        'windows_view', 'bathroom_type', 'pets_allowed', 'amenities',
#        'ceiling_height', 'elevator', 'garbage_chute'],
#       dtype='object')

# %%
# выбираем пропущенные значения из датафрейма
pd.DataFrame((data_df.isna().mean() * 100) \
            .sort_values(ascending=False) \
            .round(2) \
            .reset_index()) \
            .rename(columns={
                    'index': 'Название столбца',
                    0: 'Процент пропусков, %'
})
# Out:
#    Название столбца  Процент пропусков, %
# 0             ad_id                   0.0
# 1             rooms                   0.0
# 2             metro                   0.0
# 3           address                   0.0
# 4        total_area                   0.0
# 5     building_type                   0.0
# 6           parking                   0.0
# 7             price                   0.0
# 8       description                   0.0
# 9   renovation_type                   0.0
# 10          balcony                   0.0
# 11     windows_view                   0.0
# 12    bathroom_type                   0.0
# 13     pets_allowed                   0.0
# 14        amenities                   0.0
# 15   ceiling_height                   0.0
# 16         elevator                   0.0
# 17    garbage_chute                   0.0

# %%
data_df.head()
# Out:
#        ad_id            rooms                         metro  \
# 0  271271157                4  м. Смоленская (9 мин пешком)
# 1  271634126                4  м. Смоленская (8 мин пешком)
# 2  271173086  4, Оба варианта  м. Смоленская (7 мин пешком)
# 3  272197456  4, Оба варианта  м. Смоленская (3 мин пешком)
# 4  273614615                2   м. Арбатская (7 мин пешком)
#
#                             address       total_area  \
# 0     Москва, улица Новый Арбат, 27       200.0/20.0
# 1     Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2     Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3  Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4     Москва, улица Новый Арбат, 15    58.0/38.0/5.0
#
#                building_type    parking  \
# 0           5/16, Монолитный  подземная
# 1  5/16, Монолитно-кирпичный  подземная
# 2                       5/16  подземная
# 3                        5/6  подземная
# 4           12/26, Панельный   наземная
#
#                                                price  \
# 0  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 2  500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 3  400000.0 руб./ За месяц, Залог - 400000 руб., ...
# 4  225000.0 руб./ За месяц, Залог - 225000 руб., ...
#
#                                          description renovation_type  \
# 0  Без комиссии для нанимателя! Бонус коллегам 12...    Дизайнерский
# 1  Лот 93107. Елена Анисимова.\n\nБонус агенту 50...    Дизайнерский
# 2  ID 36380:  Шикарная 4-х км. квартира в ЖК "Нов...      Евроремонт
# 3  ID 31618:  Эксклюзивное предложение. Современн...      Евроремонт
# 4  Лот 111542. Татьяна Лучкина.\n\nБонус агенту 5...      Евроремонт
#
#                   balcony     windows_view                    bathroom_type  \
# 0              Лоджия (1)  На улицу и двор                   Раздельный (2)
# 1              Лоджия (1)  На улицу и двор  Совмещенный (2), Раздельный (1)
# 2              Лоджия (1)  На улицу и двор                  Совмещенный (3)
# 3              Балкон (1)  На улицу и двор                  Совмещенный (3)
# 4  Балкон (1), Лоджия (1)  На улицу и двор                  Совмещенный (2)
#
#                         pets_allowed  \
# 0  Можно с детьми, Можно с животными
# 1                     Можно с детьми
# 2                     Можно с детьми
# 3                  Можно с животными
# 4                         не указано
#
#                                            amenities  ceiling_height  \
# 0  Мебель в комнатах, Мебель на кухне, Ванна, Душ...             3.0
# 1  Мебель в комнатах, Мебель на кухне, Ванна, Душ...             3.5
# 2  Мебель в комнатах, Мебель на кухне, Ванна, Душ...             3.2
# 3  Мебель в комнатах, Мебель на кухне, Ванна, Душ...             3.2
# 4  Мебель в комнатах, Мебель на кухне, Ванна, Душ...             3.9
#
#              elevator garbage_chute
# 0  Пасс (4), Груз (1)            Да
# 1  Пасс (1), Груз (1)           Нет
# 2            Пасс (1)            Да
# 3            Пасс (1)            Да
# 4  Пасс (1), Груз (1)            Да

# %% [markdown]
# Названия столбцов переименованы на английский в стиле snake_case.
#
# В каждой колонке должны отсутствовать пропущенные значения (NaN, None и т.д.)

# %% [markdown]
# Сохраняем файл в католог релиза 2

# %%
data_df.to_csv('data.csv', index=False)
